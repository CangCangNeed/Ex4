# %% [markdown]
# Write a simple program for a card Role-Playing Game. Try to use only the concepts you have learned so far in the lectures.
#
# REQUIREMENTS:
#
# 1. Following are the different cards, with their characteristics, available to the player
#
# Name: Diablo
# Health: 100
# Attack: 90
# Defense: 60
#
# Name: Medusa
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Jester
# Health: 120
# Attack: 60
# Defense: 90
#
# Name: Troll
# Health: 150
# Attack: 40
# Defense: 94
#
# Name: Specter
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Mist
# Health: 100
# Attack: 75
# Defense: 65
#
# Name: Savage
# Health: 100
# Attack: 90
# Defense: 50
#
# Name: Marauder
# Health: 100
# Attack: 85
# Defense: 50
#
# Name: Wimp
# Health: 110
# Attack: 40
# Defense: 85
#
# Name: Sorcerer
# Health: 100
# Attack: 70
# Defense: 55
#
# 2. Store the above card details using a suitable data structure like list, tuple, dictionary, or any combination of these
# 3. From these cards, assign a random deck of 5 cards to both the player and the computer (opponent).
#     3.1. This should happen whenever a new game begins
# 4. Keep the game running for as long as there are cards in the player's deck or for as long as there are cards in the opponent's deck
#     4.1. Show all the cards that the player has in their deck
#     4.2. Assign a random card to the opponent, and show that to the player, along with the details of that card. Only the details of this random card must be shown.
#     4.3. Ask the player to pick a card from their own deck to fight the opponent's card.
#     4.4. If the attack value of the player's card is more than the health of opponent's card, then the player wins this round.
#     4.5. Otherwise, the player's card will fight with the opponent's card.
#         4.5.1. Calculate the damage the player's card does to the opponent's card. This calculation should take care of the fact that the opponent's card will first defend the attack using its 'Defense' value. And if there is no defense value, only then will the player's attack value will affect the opponent card's health.
#
#         e.g.,
#         Player card
#
#         Name: Wimp
#         Health: 110
#         Attack: 40
#         Defense: 85
#
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 55
#
#         If the Wimp attacks Sorcerer, first, it will only affect Sorcerer's 'Defense' value. Sorcerer's defense value will decrease by the the attack value of player's Wimp card. Therefore, after the attack, the defense value will change from 55 to 15, as 55 - 40 = 15. Therefore,
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 15
#
#         Now, if in the next round, Wimp attacks Sorcerer again, then Sorcerer's defense value will decrease to 0, but its health will also be affected. The health will be affected by 25 points, as 40 - 15 = 25. So, Sorcerer's health will now decrease from 100 to 75
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 75
#         Attack: 70
#         Defense: 0
#
#         Now, let's say in a later round, the player uses the Marauder card, which has an attack value of 85, and the computer is using Sorcerer, whose health value is 75.
#
#         In that case, Sorcerer will be defeated, as 85 > 75. When this happens, remove the Sorcerer card from the deck of the opponent.
#
#         Display properly all these changes to the player at every round, so that they know how their attacks affected the round and what they can do next.
#
#         DO NOT just show the card details. Write proper statements, describing the process, as you may have seen in the demonstration given by the teacher
#
#         4.5.2. After the user's turn, make sure all the card values adjusted accordingly, just as described above.
#         4.5.3. ONLY a card's 'Defense' and 'Health' value changes after an attack. And once the 'Health' value of a card reaches 0 or drops below it, that card MUST be removed from the deck.
#         4.5.4. After the player's turn, pause the second for some seconds, e.g., time.sleep(3) will pause the game for 3 seconds.
#     4.6. Display that now it's the opponent's turn.
#     4.7. Make sure there are cards available in opponent's deck. If there aren't, then the game ends and the player wins.
#     4.8. If there are still cards available in opponent's deck, draw a random card from the opponent's deck, and display its details to the player.
#     4.9. Then display the cards available in the player's deck.
#     4.10 Ask the user to pick one card from their own deck to fight the opponent's card.
#     4.11. REPEAT THE SAME LOGIC AS STATED FROM POINT 4.4 TO 4.5.3. But this time, from the perspective of the opponent.
#     4.12. After the opponent's turn is over, display that a new round will begin in some seconds.
# 5. If it's found that the opponent has no card in their deck, then display a message stating player is the winner, otherwise display that the opponent won.

# %%
import random
import time

# Store all the cards in this big deck using a suitable data structure
card_dict = {
    'card1': {'Name': 'Diablo', 'Health': 100, 'Attack': 90, 'Defense': 60},
    'card2': {'Name': 'Medusa', 'Health': 100, 'Attack': 70, 'Defense': 70},
    'card3': {'Name': 'Jester', 'Health': 120, 'Attack': 60, 'Defense': 90},
    'card4': {'Name': 'Troll', 'Health': 150, 'Attack': 40, 'Defense': 94},
    'card5': {'Name': 'Specter', 'Health': 100, 'Attack': 70, 'Defense': 70},
    'card6': {'Name': 'Mist', 'Health': 100, 'Attack': 75, 'Defense': 65},
    'card7': {'Name': 'Savage', 'Health': 100, 'Attack': 90, 'Defense': 50},
    'card8': {'Name': 'Marauder', 'Health': 100, 'Attack': 85, 'Defense': 50},
    'card9': {'Name': 'Wimp', 'Health': 110, 'Attack': 40, 'Defense': 85},
    'card10': {'Name': 'Sorcerer', 'Health': 100, 'Attack': 70, 'Defense': 55}
}

card_deck = list(card_dict.keys())

#This stores the number of cards each player will be given in the game.
deck_size = 5
#The following is used to draw randomly n number of cards from the deck, where n = deck_size
player_deck = random.sample(card_deck, deck_size)
opponent_deck = random.sample(card_deck, deck_size)

round_number = 1
while player_deck and opponent_deck:
    print(f"--- Round {round_number} ---")

    # 4.1.
    print("Player's deck:")
    x = 0
    while x < len(player_deck):
        card_key = player_deck[x]
        print(f"{x + 1}. {card_dict[card_key]['Name']} (Health: {card_dict[card_key]['Health']}, Attack: {card_dict[card_key]['Attack']}, Defense: {card_dict[card_key]['Defense']})")
        x += 1

    # 4.2.
    opponent_card_key = random.choice(opponent_deck)
    print("\nOpponent's card:")
    card = card_dict[opponent_card_key]
    print(f"Name: {card['Name']}")
    print(f"Health: {card['Health']}")
    print(f"Attack: {card['Attack']}")
    print(f"Defense: {card['Defense']}")
    print("")

    # 4.3. 
    valid_input = False
    while not valid_input:
        player_choice_input = input(f"Choose a card to fight (1-{len(player_deck)}): ")
        if player_choice_input.isdigit(): 
            player_choice = int(player_choice_input) - 1
            if 0 <= player_choice < len(player_deck):  
                valid_input = True
            else:
                print(f"Invalid choice. Please select a number between 1 and {len(player_deck)}.")
        else:
            print("Invalid input. Please enter a number.")

    player_card_key = player_deck[player_choice]
    print(f"\nYou chose {card_dict[player_card_key]['Name']}.\n")

    # 4.5.
    player_card = card_dict[player_card_key]
    opponent_card = card_dict[opponent_card_key]
    
    attack_value = player_card['Attack']
    opponent_defense = opponent_card['Defense']
    opponent_health = opponent_card['Health']

    if attack_value > opponent_defense:
        damage = attack_value - opponent_defense
        opponent_card['Defense'] = 0
        opponent_card['Health'] -= damage
    else:
        opponent_card['Defense'] -= attack_value

    print(f"{player_card['Name']} attacks {opponent_card['Name']}.")
    print(f"{opponent_card['Name']}'s defense is now {opponent_card['Defense']}, health is {opponent_card['Health']}.")

    if opponent_card['Health'] <= 0:
        print(f"{opponent_card['Name']} is defeated!\n")
        opponent_deck.remove(opponent_card_key)
    
    time.sleep(3)

    # 4.7.
    if not opponent_deck:
        print("You have defeated all the opponent's cards. You win!")
        break

    # 4.6.
    print("\nOpponent's turn...")
    time.sleep(3)
    opponent_attack_choice = random.choice(opponent_deck)
    print(f"Opponent chose {card_dict[opponent_attack_choice]['Name']} to attack your card.\n")

    opponent_card = card_dict[opponent_attack_choice]
    player_card = card_dict[player_card_key]
    
    attack_value = opponent_card['Attack']
    player_defense = player_card['Defense']
    player_health = player_card['Health']

    if attack_value > player_defense:
        damage = attack_value - player_defense
        player_card['Defense'] = 0
        player_card['Health'] -= damage
    else:
        player_card['Defense'] -= attack_value

    print(f"{opponent_card['Name']} attacks {player_card['Name']}.")
    print(f"{player_card['Name']}'s defense is now {player_card['Defense']}, health is {player_card['Health']}.")

    if player_card['Health'] <= 0:
        print(f"{player_card['Name']} is defeated!\n")
        player_deck.remove(player_card_key)

    # 4.7.
    if not player_deck:
        print("All your cards have been defeated. The opponent wins!")
        break

    # 4.12.
    round_number += 1
    print("\nA new round will begin in 3 seconds\n")
    time.sleep(3)
# Out:
# --- Round 1 ---
# Player's deck:
# 1. Diablo (Health: 100, Attack: 90, Defense: 60)
# 2. Wimp (Health: 110, Attack: 40, Defense: 85)
# 3. Troll (Health: 150, Attack: 40, Defense: 94)
# 4. Medusa (Health: 100, Attack: 70, Defense: 70)
# 5. Mist (Health: 100, Attack: 75, Defense: 65)
#
# Opponent's card:
# Name: Marauder
# Health: 100
# Attack: 85
# Defense: 50
#
#
# You chose Medusa.
#
# Medusa attacks Marauder.
# Marauder's defense is now 0, health is 80.
#
# Opponent's turn...
# Opponent chose Marauder to attack your card.
#
# Marauder attacks Medusa.
# Medusa's defense is now 0, health is 85.
#
# A new round will begin in 3 seconds
#
# --- Round 2 ---
# Player's deck:
# 1. Diablo (Health: 100, Attack: 90, Defense: 60)
# 2. Wimp (Health: 110, Attack: 40, Defense: 85)
# 3. Troll (Health: 150, Attack: 40, Defense: 94)
# 4. Medusa (Health: 85, Attack: 70, Defense: 0)
# 5. Mist (Health: 100, Attack: 75, Defense: 65)
#
# Opponent's card:
# Name: Medusa
# Health: 85
# Attack: 70
# Defense: 0
#
#
# You chose Troll.
#
# Troll attacks Medusa.
# Medusa's defense is now 0, health is 45.
#
# Opponent's turn...
# Opponent chose Medusa to attack your card.
#
# Medusa attacks Troll.
# Troll's defense is now 24, health is 150.
#
# A new round will begin in 3 seconds
#
# --- Round 3 ---
# Player's deck:
# 1. Diablo (Health: 100, Attack: 90, Defense: 60)
# 2. Wimp (Health: 110, Attack: 40, Defense: 85)
# 3. Troll (Health: 150, Attack: 40, Defense: 24)
# 4. Medusa (Health: 45, Attack: 70, Defense: 0)
# 5. Mist (Health: 100, Attack: 75, Defense: 65)
#
# Opponent's card:
# Name: Wimp
# Health: 110
# Attack: 40
# Defense: 85
#
#
# You chose Mist.
#
# Mist attacks Wimp.
# Wimp's defense is now 10, health is 110.
#
# Opponent's turn...
# Opponent chose Specter to attack your card.
#
# Specter attacks Mist.
# Mist's defense is now 0, health is 95.
#
# A new round will begin in 3 seconds
#
# --- Round 4 ---
# Player's deck:
# 1. Diablo (Health: 100, Attack: 90, Defense: 60)
# 2. Wimp (Health: 110, Attack: 40, Defense: 10)
# 3. Troll (Health: 150, Attack: 40, Defense: 24)
# 4. Medusa (Health: 45, Attack: 70, Defense: 0)
# 5. Mist (Health: 95, Attack: 75, Defense: 0)
#
# Opponent's card:
# Name: Medusa
# Health: 45
# Attack: 70
# Defense: 0
#
#
# You chose Medusa.
#
# Medusa attacks Medusa.
# Medusa's defense is now 0, health is -25.
# Medusa is defeated!
#
#
# Opponent's turn...
# Opponent chose Wimp to attack your card.
#
# Wimp attacks Medusa.
# Medusa's defense is now 0, health is -65.
# Medusa is defeated!
#
#
# A new round will begin in 3 seconds
#
# --- Round 5 ---
# Player's deck:
# 1. Diablo (Health: 100, Attack: 90, Defense: 60)
# 2. Wimp (Health: 110, Attack: 40, Defense: 10)
# 3. Troll (Health: 150, Attack: 40, Defense: 24)
# 4. Mist (Health: 95, Attack: 75, Defense: 0)
#
# Opponent's card:
# Name: Marauder
# Health: 80
# Attack: 85
# Defense: 0
#
#
# You chose Diablo.
#
# Diablo attacks Marauder.
# Marauder's defense is now 0, health is -10.
# Marauder is defeated!
#
#
# Opponent's turn...
# Opponent chose Specter to attack your card.
#
# Specter attacks Diablo.
# Diablo's defense is now 0, health is 90.
#
# A new round will begin in 3 seconds
#
# --- Round 6 ---
# Player's deck:
# 1. Diablo (Health: 90, Attack: 90, Defense: 0)
# 2. Wimp (Health: 110, Attack: 40, Defense: 10)
# 3. Troll (Health: 150, Attack: 40, Defense: 24)
# 4. Mist (Health: 95, Attack: 75, Defense: 0)
#
# Opponent's card:
# Name: Specter
# Health: 100
# Attack: 70
# Defense: 70
#
# Invalid input. Please enter a number.
#
# You chose Mist.
#
# Mist attacks Specter.
# Specter's defense is now 0, health is 95.
#
# Opponent's turn...
# Opponent chose Sorcerer to attack your card.
#
# Sorcerer attacks Mist.
# Mist's defense is now 0, health is 25.
#
# A new round will begin in 3 seconds
#
# --- Round 7 ---
# Player's deck:
# 1. Diablo (Health: 90, Attack: 90, Defense: 0)
# 2. Wimp (Health: 110, Attack: 40, Defense: 10)
# 3. Troll (Health: 150, Attack: 40, Defense: 24)
# 4. Mist (Health: 25, Attack: 75, Defense: 0)
#
# Opponent's card:
# Name: Specter
# Health: 95
# Attack: 70
# Defense: 0
#
# Invalid input. Please enter a number.
#
# You chose Troll.
#
# Troll attacks Specter.
# Specter's defense is now 0, health is 55.
#
# Opponent's turn...
# Opponent chose Specter to attack your card.
#
# Specter attacks Troll.
# Troll's defense is now 0, health is 104.
#
# A new round will begin in 3 seconds
#
# --- Round 8 ---
# Player's deck:
# 1. Diablo (Health: 90, Attack: 90, Defense: 0)
# 2. Wimp (Health: 110, Attack: 40, Defense: 10)
# 3. Troll (Health: 104, Attack: 40, Defense: 0)
# 4. Mist (Health: 25, Attack: 75, Defense: 0)
#
# Opponent's card:
# Name: Specter
# Health: 55
# Attack: 70
# Defense: 0
#
#
# You chose Mist.
#
# Mist attacks Specter.
# Specter's defense is now 0, health is -20.
# Specter is defeated!
#
#
# Opponent's turn...
# Opponent chose Wimp to attack your card.
#
# Wimp attacks Mist.
# Mist's defense is now 0, health is -15.
# Mist is defeated!
#
#
# A new round will begin in 3 seconds
#
# --- Round 9 ---
# Player's deck:
# 1. Diablo (Health: 90, Attack: 90, Defense: 0)
# 2. Wimp (Health: 110, Attack: 40, Defense: 10)
# 3. Troll (Health: 104, Attack: 40, Defense: 0)
#
# Opponent's card:
# Name: Sorcerer
# Health: 100
# Attack: 70
# Defense: 55
#
#
# You chose Troll.
#
# Troll attacks Sorcerer.
# Sorcerer's defense is now 15, health is 100.
#
# Opponent's turn...
# Opponent chose Sorcerer to attack your card.
#
# Sorcerer attacks Troll.
# Troll's defense is now 0, health is 34.
#
# A new round will begin in 3 seconds
#
# --- Round 10 ---
# Player's deck:
# 1. Diablo (Health: 90, Attack: 90, Defense: 0)
# 2. Wimp (Health: 110, Attack: 40, Defense: 10)
# 3. Troll (Health: 34, Attack: 40, Defense: 0)
#
# Opponent's card:
# Name: Sorcerer
# Health: 100
# Attack: 70
# Defense: 15
#
# Invalid input. Please enter a number.
#
# You chose Troll.
#
# Troll attacks Sorcerer.
# Sorcerer's defense is now 0, health is 75.
#
# Opponent's turn...
# Opponent chose Sorcerer to attack your card.
#
# Sorcerer attacks Troll.
# Troll's defense is now 0, health is -36.
# Troll is defeated!
#
#
# A new round will begin in 3 seconds
#
# --- Round 11 ---
# Player's deck:
# 1. Diablo (Health: 90, Attack: 90, Defense: 0)
# 2. Wimp (Health: 110, Attack: 40, Defense: 10)
#
# Opponent's card:
# Name: Sorcerer
# Health: 75
# Attack: 70
# Defense: 0
#
#
# You chose Diablo.
#
# Diablo attacks Sorcerer.
# Sorcerer's defense is now 0, health is -15.
# Sorcerer is defeated!
#
#
# Opponent's turn...
# Opponent chose Wimp to attack your card.
#
# Wimp attacks Diablo.
# Diablo's defense is now 0, health is 50.
#
# A new round will begin in 3 seconds
#
# --- Round 12 ---
# Player's deck:
# 1. Diablo (Health: 50, Attack: 90, Defense: 0)
# 2. Wimp (Health: 110, Attack: 40, Defense: 10)
#
# Opponent's card:
# Name: Wimp
# Health: 110
# Attack: 40
# Defense: 10
#
#
# You chose Wimp.
#
# Wimp attacks Wimp.
# Wimp's defense is now 0, health is 80.
#
# Opponent's turn...
# Opponent chose Wimp to attack your card.
#
# Wimp attacks Wimp.
# Wimp's defense is now 0, health is 40.
#
# A new round will begin in 3 seconds
#
# --- Round 13 ---
# Player's deck:
# 1. Diablo (Health: 50, Attack: 90, Defense: 0)
# 2. Wimp (Health: 40, Attack: 40, Defense: 0)
#
# Opponent's card:
# Name: Wimp
# Health: 40
# Attack: 40
# Defense: 0
#
#
# You chose Wimp.
#
# Wimp attacks Wimp.
# Wimp's defense is now 0, health is 0.
# Wimp is defeated!
#
# You have defeated all the opponent's cards. You win!
